# %% [markdown]
# <a href="https://colab.research.google.com/github/DinaTTomoum/Thesis2021/blob/main/trump20ngrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the libraries
import tweepy
from textblob import TextBlob
import pandas as pd
import numpy as np
# Import re is regular expressions
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import nltk
from nltk.corpus import stopwords
import spacy
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# load in all the modules for ngram
import nltk, re, string, collections
from nltk.util import ngrams # function for making ngrams
from nltk import FreqDist

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-adff8707-ffb0-4ec3-8a03-f58593ea2f27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-adff8707-ffb0-4ec3-8a03-f58593ea2f27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Trump2020.csv to Trump2020 (1).csv

# %%
import pandas as pd
data = pd.read_csv('Trump2020 (1).csv', encoding= 'unicode_escape')

# %%
#Frequency of Tweets Per month
data['date'] = pd.to_datetime(data['date'], errors='coerce')
data.groupby([data['date'].dt.year.rename('year'), data['date'].dt.month.rename('month')]).agg({'count'})
# Out:
#            handle Election  text  ... place_name place_country source_url
#             count    count count  ...      count         count      count
# year month                        ...
# 2020 1        964      964   964  ...          0             0          0
#      2        899      899   899  ...          0             0          0
#      3        970      970   970  ...          0             0          0
#      4        840      840   840  ...          0             0          0
#      5       1121     1121  1121  ...          0             0          0
#      6       1119     1119  1119  ...          0             0          0
#      7        869      869   869  ...          0             0          0
#      8       1121     1121  1121  ...          0             0          0
#      9       1363     1363  1363  ...          0             0          0
#      10      1415     1415  1415  ...          0             0          0
#      11       912      912   912  ...          0             0          0
#      12       643      643   643  ...          0             0          0
#
# [12 rows x 16 columns]

# %%
data.head()
# Out:
#         handle  Election  ... place_country  source_url
# 0  DonaldTrump      2020  ...           NaN         NaN
# 1  DonaldTrump      2020  ...           NaN         NaN
# 2  DonaldTrump      2020  ...           NaN         NaN
# 3  DonaldTrump      2020  ...           NaN         NaN
# 4  DonaldTrump      2020  ...           NaN         NaN
#
# [5 rows x 16 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'


def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet


# # cleaning master function
# def clean_tweet(tweet, bigrams=False):
#     tweet = remove_users(tweet)
#     tweet = remove_links(tweet)
#     tweet = tweet.lower() # lower case
#     tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
#     tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
#     tweet = re.sub(r'[^\x00-\x7F]+','', tweet)
#     tweet_token_list = [word for word in tweet.split(' ')
#                             if word not in my_stopwords] # remove stopwords

#     if bigrams:
#         tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
#                                             for i in range(len(tweet_token_list)-1)]
#     tweet = ' '.join(tweet_token_list)
#     return tweet


#create a function to clean the tweets
def cleanTxt(text) :
  text = remove_users(text)
  text = remove_links(text)
  text = text.lower() # lower case
  text = re.sub('['+my_punctuation + ']+', ' ', text) # strip punctuation
  text = re.sub('([0-9]+)', '', text) # remove numbers
  text = re.sub(r'[^\x00-\x7F]+','', text)

  text = re.sub('@[^A-Za-z0-9^,!.\/+-=]', '', text) #remove mentions
  text = re.sub(r'#', '', text) #remove the hashtag symbol
  text= re.sub(r'RT[\s]+', '', text) #removing RT (retweets) text 
  text = re.sub(r'https?:\/\/\S+', '', text) #remove hyperlink
  text = re.sub('ENDOFARTICLE.','', text) # get rid of the "ENDOFARTICLE." text
  tweet_token_list = [word for word in text.split(' ')
                            if word not in my_stopwords] # remove stopwords
  text = ' '.join(tweet_token_list)

  return text
df_cln= data.text.apply(cleanTxt)
cln = [' '.join(df_cln)]
listToStr = ' '.join(map(str, cln))   
#print(listToStr) # unhyphenate in case you want to see it
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df_cln
# Out:
# 0        thrilled back great city charlotte  north caro...
# 1          read  letter surveillance court obtained cbs...
# 2        unsolicited mail ballot scam major threat demo...
# 3          friendly telling events comey apparent leaki...
# 4          president  announced historic steps protect ...
#                                ...
# 12585      dont know  thinks continue lie  \n\nhe wants...
# 12586      president  excels communicating directly ame...
# 12587      live  presidential debate debates\n\ntext vo...
# 12588    signed order support workers delphi corporatio...
# 12589    suburban women want safety  amp  security  joe...
# Name: text, Length: 12590, dtype: object

# %%
import nltk
from nltk.util import ngrams
nltk.download('punkt')

# Function to generate n-grams from sentences.
def extract_ngrams(data, num):
    n_grams = ngrams(nltk.word_tokenize(data), num)
    return [ ' '.join(grams) for grams in n_grams]
onegram = ("1-gram: ", extract_ngrams(listToStr, 1))
twogram = ("2-gram: ", extract_ngrams(listToStr, 2))
threegram = ("3-gram: ", extract_ngrams(listToStr, 3))
fourgram = ("4-gram: ", extract_ngrams(listToStr, 4))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
fourgram[1][1:4]
# Out:
# ['back great city charlotte',
#  'great city charlotte north',
#  'city charlotte north carolina']

# %%
unigramFreq = collections.Counter(list(onegram[1]))
trigramFreq = collections.Counter(list(threegram[1]))
bigramFreq = collections.Counter(list(twogram[1]))
quadgramFreq = collections.Counter(list(fourgram[1]))
quadgramFreq.most_common(10)
# Out:
# [('approval rating republican party', 42),
#  ('live press briefing coronavirus', 29),
#  ('press briefing coronavirus task', 29),
#  ('briefing coronavirus task force', 29),
#  ('live president holds news', 28),
#  ('president holds news conference', 28),
#  ('rating republican party thank', 23),
#  ('radical left nothing democrats', 22),
#  ('complete amp total endorsement', 19),
#  ('white house news conference', 18)]

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS) 
wordcloud = WordCloud(width = 800, height = 800, 
            background_color ='white', 
            stopwords = stopwords, 
            min_font_size = 10).generate(str(df_cln))

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title ("Trump 2020 WordCloud", size=24)
plt.show()

# %%
top30 = bigramFreq.most_common(30)

# %%
top30quad = quadgramFreq.most_common(30)

# %%
top30[1][1]

# %%
import matplotlib.pyplot as plt
top30  = [list(elem) for elem in top30]
xs, ys = [*zip(*top30)]
plt.figure(figsize=(20,15), )
plt.rcParams.update({'font.size': 22})
plt.barh(xs,ys)
plt.title ("Top 30 Three Grams")
